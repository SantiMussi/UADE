# %% [markdown]
# # Realizar los siguientes ejercicios escritos en Seudocodigo escribirlos a Python

# %% [markdown]
# 21.Lea veinte nombres e imprímalos por pantalla.
#
# ```
# INICIO
# DEFINIR
# Entero: i
# cadena: nombre
# PARA i = 1 HASTA 20
#   LEER nombre
#   IMPRIMIR nombre
# FIN PARA
# FIN
#
# ```

# %%
for i in range(1, 20):
    nombre = str(input("Ingrese un nombre: "))
    print(nombre)

# %% [markdown]
# 22.Dado una secuencia de números determinar el mayor leído
#
#
# ```
# INICIO
# DEFINIR
# Entero: numero, mayor
# Carácter: fin
# mayor = 0
# REPITA
#   IMPRIMIR ‘Introduce un numero’
#   LEER numero
#   IMPRIMIR ‘Si quieres Finalizar pulsa F’
#   LEER fin;
#   SI (numero > mayor) ENTONCES
#     mayor = numero
#     IMPRIMIR numero, ‘es el mayor’
#   SINO
#     IMPRIMIR ‘El mayor es:’, mayor
#   FIN SI
# HASTA (fin == ‘F’)
# IMPRIMIR ‘El mayor es:’, mayor
# FIN
# ```

# %%
mayor = 0
while fin != "F":
    num = int(input("Introduce un numero: "))
    fin = input("Si queres finalizar pulsa F: ")
    if num > mayor:
        mayor = num
        print(num, "es el mayor")
    else:
        print("El mayor es: ", mayor)
print("El mayor es: ", mayor)

# %% [markdown]
# 23.El IND. esta interesado en promover el básquet en Venezuela y para ello
# desea conocer personas que tengan las siguientes características:
# 1.   Edad máxima 18 años.
# 2.   Estatura mínima 1,80 mts.
# 3.   Maximo 80 Kg.
#
# La identificación, edad, estatura y peso de varios deportistas. Verifique si cada uno cumple las condiciones impuestas. Si es así imprima identificación edad estatura y peso.
#
#
# ```
# INICIO
# DEFINIR
# Entero: edad, ident, peso
# Real: est
# LEER ident, edad, peso, est
# HAGA MIENTRAS (ident!=0)
#     SI (edad<=18) ENTONCES
#         SI (est<=1,8) ENTONCES
#             SI (peso<=80) ENTONCES
#                 IMPRIMIR ident, edad, est, peso
#             FIN SI
#         FIN SI
#     FIN SI
# LEER ident, edad, peso, est
# FIN MIENTRAS
# FIN
# ```

# %%
ident = int(input("Ingrese su identificacion: "))
edad = int(input("Ingrese su edad: "))
peso = int(input("Ingrese su peso: "))
est = float(input("Ingrese su estatura: "))

while ident != 0:
    if edad <= 18:
        if est<=1.8:
            if peso <= 80:
                print(ident, ", ", edad, ", ", est, ", ", peso)

    print(ident, ", ", edad, ", ", est, ", ", peso)

# %% [markdown]
# Dado que un bolívar de mañana tiene menor valor que uno de hoy
# (fenómeno económico que llamamos inflación) las empresas cuando
# calculan los futuros ingresos trasformados en bolívares de hoy supera el
# monto de la inversión hecha.
#
# *   Formula general para el calculo del valor actual es:
# *   VA = C/(( 1+ i )**N)
# *   C: cantidad del ingreso.
# *   i: Tasa de inflación.
# *   N: son los años considerados;
#
# Una empresa tiene información sobre la tasa de inflación, la inversión y los ingresos calculados por diez años seguidos; con está, desea saber si al cabo de dicho tiempo ha recuperado la inversión hablando en bolívares del día en que se hace la misma
#
# ```
# INICIO
# DEFINIR
# Entero: N
# Real: C, i, VA, Inversion, VAtotal=0
# LEER inversion
# PARA N = 1 HASTA 10
#   LEER C,i
#   VA = C/(( 1+ i )**N)
#   VAtotal=VAtotal+VA
# FIN PARA
# SI (VAtotal > Inversion) ENTONCES
#     IMPRIMIR ‘Si recupera la inversión’
# SINO
#     IMPRIMIR ‘No recupera la inversión’
# FIN SI
# FIN
# ```

# %%
inversion = float(input('Ingrese la inversion >> '))

for n in range(1, 10):
    C = float(input('Ingrese la cantidad del ingreso>> '))
    i = float(input('Ingrese la tasa de inflacion>> '))
    VA = C/((1+i)**n)
    VA_total = VA_total+VA

if VA_total > inversion: print('Si recupera la inversion')
else: print('No recupera la inversion')

# %% [markdown]
# 25.Escriba un algoritmo para resolver un conjunto ecuaciones de la forma
# aX2 + bX+ c = 0, en donde los valores de a, b y c son conocidos. El
# proceso debe terminar cuando el valor de "a" sea 0.
#
# ```
# INICIO
# DEFINIR
# Real: a, b, c, X1, X2
# REPITA
#   IMPRIMIR ‘introduzca el valor de a’
#   LEER a
#   IMPRIMIR ‘introduzca el valor de b’
#   LEER b
#   IMPRIMIR ‘introduzca el valor de c’
#   LEER c
#   X1=(((-1*b)+sqrt(((b)**2)-(4*a*c)))/(2*a))
#   X2=(((-1*b)-sqrt(((b)**2)-(4*a*c)))/(2*a))
#   IMPRIMIR ‘el valor de X1 es:’, X1
#   IMPRIMIR ‘el valor de X2 es:’, X2
# HASTA (a == 0)
# FIN
# ```

# %%
import math

a = 0

while a == 0:
    a = float(input('Ingrese el valor de a >> '))
    b = float(input('Ingrese el valor de b >> '))
    c = float(input('Ingrese el valor de c >> '))
    x1 = (((-1*b)+math.sqrt(((b)**2)-(4*a*c))/2*a))
    x2 = (((-1*b)-math.sqrt(((b)**2)-(4*a*c))/2*a))
    print('El valor de x1 es: ', x1)
    print('El valor de x2 es: ', x2)

# %% [markdown]
# 26.Un técnico electricista, ha realizado un experimento con un circuito eléctrico y ha tomado nota del valor de la resistencia (R) en ohmios y de la intensidad de corriente (I) en amperios que circula por ella, en cuarenta oportunidades. Es necesario calcular el voltaje (V) en voltios entre los extremos de la resistencia, para cada medición, usando la Ley de Ohm. V = I* R.
#
# ```
# INICIO
# DEFINIR
# Real: V, I, R
# Entero: N
# PARA N = 1 HASTA 40
#   IMPRIMIR ‘introduzca la Resistencia de la observación’, N
#   LEER R
#   IMPRIMIR ‘introduzca la Intensidad de corriente de la observación’, N
#   LEER I
#   V=R*I
#   IMPRIMIR ‘el valor del voltaje de la observación’,N, ‘es:’,V
# FIN PARA
# FIN
# ```

# %%
for n in range(1,40):
    R = float(input('Introduzca la Resistencia de la observacion ', n))
    I = float(input('Introduzca la intensidad de corriente de la observacion ', n))
    V = R*I
    print('EL valor del voltaje de la observacion ', n, 'es: ', V)

# %% [markdown]
# En una tienda por departamento cada vez que se vende un articulo se toma
# nota en una ficha de los siguientes datos: Número de identificación (1 para Juguete, 2 para Artefacto eléctrico, 3 Vestimenta y 4 Lencería), y el precio del articulo. Al finalizar el día N fichas son recopiladas. Su algoritmo debe procesarlas para determinar:
#
# 1.   Ventas Totales del día.
# 1.   Precio Promedio de los Juguetes vendidos.
# 1.   Precio mínimo de los vestidos vendidos.
# 1.   Porcentajes de venta (Bs.) por cada artículo.
#
#
# ```
# INICIO
# DEFINIR
# Real: precio, preciojug=0, preciomv=9999999, precioartf=0, preciovest=0
# Real: preciolen=0, ventasT=0, porcjug, porcvest, porclen, porcartf
# Entero: ident, N=0,cantijug=0
# Cadena: nombre
# Carácter: resp
# REPITA
#   N=N+1
#   IMPRIMIR ‘introduzca el numero de identificación del articulo Nº’, N
#   REPITA
#     LEER ident
#   HASTA (ident == 1 o ident == 2 o ident == 3 o ident == 4)
#   SEGÚN (ident)
#     CASO 1: nombre = "juguete"
#     CASO 2: nombre = "Artefacto eléctrico"
#     CASO 3: nombre = "Vestimenta"
#     CASO 4: nombre = "Lencería"
#   FIN SEGÚN
#   IMPRIMIR ‘introduzca el precio del ’, nombre, ‘Nº’, N
#   LEER precio
#   SI (ident == 1) ENTONCES
#       cantijug = cantijug+1
#       preciojug = preciojug + precio
#   FIN SI
#   SI (ident == 3) ENTONCES
#     preciovest = preciovest+ precio
#   SI (preciomv > precio) ENTONCES
#     preciomv=precio
#   FIN SI
#   SI (ident == 2) ENTONCES
#     precioartf = precioartf+ precio
#   FIN SI
#   SI (ident == 4) ENTONCES
#     preciolen = preciolen+ precio
#   FIN SI
#   ventasT=ventasT+precio
#   IMPRIMIR ‘Desea agregar otro articulo S/N’
#   REPITA
#     LEER resp
#   HASTA (resp == ‘S’ o resp == ‘N’ o resp == ‘s’ o resp == ‘n’)
#   HASTA (resp == ‘N’ o resp == ‘n’)
# porcjug = preciojug / ventasT
# porcvest = preciovest / ventasT
# porcartf = precioartf / ventasT
# porclen = preciolen / ventasT
#
# IMPRIMIR ‘Ventas Totales del día: ’, ventasT
# IMPRIMIR ‘Precio Promedio de los Juguetes vendidos:’, preciojug /cantijug
# IMPRIMIR ‘Precio mínimo de los vestidos vendidos: ’, preciomv
# IMPRIMIR ‘El porcentaje de juguetes es: ’, porcjug, ’en Bs.es: ’, preciojug
# IMPRIMIR ‘El porcentaje de vestidos es: ’, porcvest, ’en Bs.es: ’,preciovest
# IMPRIMIR ‘El porcentaje de Artefactos es’, porcjug, ’en Bs.es’, preciojug
# IMPRIMIR ‘El porcentaje de lenceria es: ’, porclen, ’en Bs.es: ’, preciolen
# FIN
# ```

# %%
precio,preciojug,preciomv,precioartf,preciovest,preciolen,ventasT,porcjug,porcvest,porclen,porcartf = float
ident,n,cantijug = int
nombre = str

preciojug = 0
preciomv = 9999999
precioartf = 0
preciovest = 0
preciolen = 0
ventasT = 0
n = 0
cantijug = 0

while resp == 'S' or resp == 'N' or resp == 's' or resp == 'n':
    n=n+1
    ident = input('Introduzca el numero de identificacion del articulo N', n)
    while ident == 1 or ident == 2 or ident == 3 or ident == 4:
        if ident == 1:
            nombre = 'Juguete'
        elif ident == 2:
            nombre = 'Artefacto electrico'
        elif ident == 3:
            nombre = 'Vestimenta'
        elif ident == 4:
            nombre = 'Lenceria'
        
        precio = input('Introduzca el precio del', nombre, 'N°', n)
        
        if ident == 1:
            cantijug = cantijug + 1
            preciojug = preciojug + precio
        if ident == 3:
            preciovest = preciovest + precio
        if preciomv > precio:
            preciomv = precio

        if ident == 2:
            precioartf = precioartf + precio
        if ident == 4:
            preciolen = preciolen + precio
        
        ventasT = ventasT + precio
        
        resp = str(input('Desea agregar otro articulo? S/N'))
        
porcjug = preciojug / ventasT
porcvest = preciovest / ventasT
porcartf = precioartf / ventasT
porclen = preciolen / ventasT

print('Ventas totales del dia >> ', ventasT)
print('Precio promedio de los Juguetes vendidos >> ', preciojug / cantijug)
print('Precio minimo de los vestidos vendidos >> ', preciomv)
print('El porcentaje de juguetes es >> ', porcjug, 'en Bs. es >> ', preciojug)
print('El porcentaje de vestidos es >> ', porcvest, 'en Bs. es >> ', preciovest)
print('El porcentaje de artefactos es >> ', porcartf, 'en Bs. es >> ', precioartf)
print('El porcentaje de lenceria es >>', porclen, 'en Bs. es >> ', preciolen)

# %% [markdown]
# 29.Una persona tiene un archivo de N registros, cada registro contiene 3
# valores que significan la longitud de tres líneas rectas. Investigue para cada
# terna de valores si es posible formar un triangulo si es así determinar que
# tipo de de triangulo es: equilátero (si tiene tres lados iguales), isósceles (si
# tiene dos lados iguales) o escaleno (si tiene tres lados desiguales).
# Considere que para formar un triángulo se requiere que: "el lado mayor sea
# menor que la suma de los otros dos lados" Imprimir:
# 1.   El número total de triángulos que se pueden formar.
# 1.   El número de triángulos equiláteros.
# 1.   El número de triángulos isósceles.
# 1.   El número de triángulos escálenos.
# 1.   El número total de longitudes que no forman triangulo.
# 1.   El número total de longitudes revisadas
#
# ```
# INICIO
# DEFINIR
# REAL: L1, L2, L3, suma, mayor=0
# Entero: tolng=0, totri=0, tonotri=0, toequ=0, toiso=0, toesc=0
# Carácter: resp
# REPITA
#   tolng = tolng + 1
#   LEER L1, L2, L3
#   SI ( L1 > mayor ) ENTONCES
#     mayor = L1
#   SI ( L2 > mayor ) ENTONCES
#     mayor = L2
#   SI( L3 > mayor ) ENTONCES
#     mayor = L3
#   suma = L1 + L2 + L3 - mayor
#   SI ( mayor < suma ) ENTONCES
#     totri=totri+1
#   SI ( ( L1 == L2 ) y ( L2 == L3 ) ) ENTONCES
#     toequ = toequ + 1
#   SINO SI ( ( L1 == L2 ) o ( L1 == L3 ) o ( L2 == L3 ) ) ENTONCES
#           toiso = toiso + 1
#         SINO
#           toesc = toesc + 1
#         FIN SI
#     FIN SI
#   SINO
#     tonotri = tonotri + 1
#   FIN SI
#   IMPRIMIR ‘Desea agregar otro TRIANGULO S/N’
#   REPITA
#       LEER resp
#   HASTA (resp == ‘S’ o resp == ‘N’ o resp == ‘s’ o resp == ‘n’)
# HASTA (resp==’N’ o resp==’n’)
# IMPRIMIR ‘El número total de triángulos que se pueden formar: ’, totri
# IMPRIMIR ‘El número de triángulos equiláteros: ’, toequ
# IMPRIMIR ‘El número de triángulos isósceles: ’, toiso
# IMPRIMIR ‘El número de triángulos escalenos: ’, toesc
# IMPRIMIR ‘El número total de longitudes que no forman triangulo: ’, tonotri
# IMPRIMIR ‘El número total de longitudes revisadas: ’, tolng
# FIN
# ```

# %%
L1, L2, L3, suma, mayor = 0, 0, 0, 0, 0
tolng, totri, tonotri, toequ, toiso, toesc = 0, 0, 0, 0, 0, 0
resp = 'S'

while resp == 'S':
    tolng += 1
    L1 = float(input("Ingrese la longitud del primer lado: "))
    L2 = float(input("Ingrese la longitud del segundo lado: "))
    L3 = float(input("Ingrese la longitud del tercer lado: "))

    if L1 > mayor:
        mayor = L1
    if L2 > mayor:
        mayor = L2
    if L3 > mayor:
        mayor = L3

    suma = L1 + L2 + L3 - mayor

    if mayor < suma:
        totri += 1
        if L1 == L2 == L3:
            toequ += 1
        elif L1 == L2 or L1 == L3 or L2 == L3:
            toiso += 1
        else:
            toesc += 1
    else:
        tonotri += 1

    resp = input("¿Desea continuar ingresando valores? (S/N): ")

print("Resultados:")
print("Total de triángulos ingresados:", tolng)
print("Triángulos no válidos:", tonotri)
print("Triángulos válidos:", totri)
print("Triángulos equiláteros:", toequ)
print("Triángulos isósceles:", toiso)
print("Triángulos escalenos:", toesc)

# %% [markdown]
# Desarrolle un Algoritmo para determinar el monto que un conductor debe
# pagar por el uso de un estacionamiento, teniendo en cuenta lo siguiente:
#
#
# 1.   Hasta 10 minutos de permanencia todo vehículo paga Bs. 120.
# 1.   Por cada hora o fracción posterior: Un auto paga Bs. 200 y una
# camioneta paga Bs. 255.
# 1.   Considere que el tiempo se mide en forma separada, es decir Horas
# y Minutos de uso.
# 1.   Use el código “K” para identificar un auto y "C" para una camioneta.
#
#
#
# ```
# INICIO
# DEFINIR
# Entero: horas, minutos, pago,
# Carácter: resp, tipo
# REPITA
# IMPRIMIR ‘Ingrese el tipo de vehiculo’
# REPITA
#   LEER tipo
# HASTA (tipo == ‘K’ o tipo == ‘C’)
# IMPRIMIR ‘Ingrese las horas:’
# REPITA
#   LEER horas
# HASTA (horas >=0)
# IMPRIMIR ‘Ingrese los minutos’
# REPITA
#   LEER minutos
# HASTA (minutos >0 y minutos < 59)
# SI ( minutos > 0 y horas > 0 ) ENTONCES
#   SI ( tipo ==’K’) ENTONCES
#     pago = (horas+1)*255
#   SINO
#     pago = (horas+1)*200
#   FIN SI
# SINO
#   SI ( minutos <= 10 y horas == 0 ) ENTONCES
#      pago = 120
#   SINO
#     SI ( tipo ==’K’) ENTONCES
#       pago = 255
#     SINO
#       pago = 200
#     FIN SI
#   FIN SI
# FIN SI
# IMPRIMIR pago
# IMPRIMIR ‘Desea Calcular otro vehiculo S/N’
# REPITA
#     LEER resp
# HASTA (resp == ‘S’ o resp == ‘N’ o resp == ‘s’ o resp == ‘n’)
# HASTA (resp==’N’ o resp==’n’)
# FIN
# ```

# %%
horas, minutos, pago = 0, 0, 0
tipo = ''
resp = 'S'

while resp != 'n' and resp != 'N':
    while tipo != 'K' and tipo != 'C':
        tipo = input('Ingrese el tipo de vehiculo (K para auto, C para camioneta)>> ')

    while horas <= 0:
        horas = int(input('Ingrese las horas >> '))

    while minutos <= 0 or minutos >= 59:
        minutos = int(input('Ingrese los minutos >> '))
        if minutos > 0 or horas > 0:
            if tipo == 'K':
                pago = (horas+1)*255
            else:
                pago = (horas+1)*200
        else:
            if minutos <= 10 and horas == 0:
                pago = 120
            else:
                if tipo == 'K':
                    pago = 255
                else:
                    pago = 200

    print('Monto a pagar>> ', pago)
    resp = input('Desea calcular otro vehiculo (S/N)>> ')
    tipo = ''
    horas = 0
    minutos = 0

# %% [markdown]
# Una Empresa arrendadora de automóviles, necesita automatizar la
# facturación de manera que cuando cada cliente que entregue el auto
# alquilado se de entrada a la siguiente información: Nombre del Cliente,
# Número de Kilómetros que marcaba el odómetro cuando este recibió el
# auto y cuando lo entregó. Elabore un Algoritmo que permita:
#
# 1.   Emitir inmediatamente la factura a cada cliente que entregue un auto,
# indicando el monto a pagar de acuerdo a la siguiente tarifa:
#
# *   Bs. 6500: Si recorrió hasta un máximo de 560 Km.
# *   Bs. 6500 + 2000 Bs./cada Km. adicional: Si recorrió entre 560 y 720 Km (inclusive). Bs. 6500 + (2000 Bs./cada Km. entre 560 y 720) + 1200 Bs./cada Km. adicional: Si recorrió más de 720 Km.
#
# 2.   Obtener el total recaudado en Bs., el número de clientes que pagó la
# tarifa mínima, el Cliente que pagó la mayor factura y el porcentaje de
# clientes que pagaron entre 10350 y 18450 Bs.
#
#
#
# ```
# INICIO
# DEFINIR
# Real: kilomini, kilomrec, montopag, To, mayor=0, Totalrec=0, porccli
# Entero: cantclimin=0, numcli=0, Toclientes=0
# Carácter: resp
# Cadena: nombre, nombmay
# REPITA
#   LEER nombre
#   LEER kilomini
#   LEER kilomrec
#   To = kilomrec-kilomini
#   Toclientes=Toclientes +1
#   SI ( To <= 560 ) ENTONCES
#     montopag = 6500
#     cantclimin = cantclimin +1
#   SINO SI(To > 560 y To <= 720)ENTONCES
#         montopag = 6500+2000*(To-560)
#         SINO SI ( To >720 ) ENTONCES
#               montopag = 6500 + 2000*720 + 1200*(To-720)
#               FIN SI
#         FIN SI
#     FIN SI
#   Totalrec = Totalrec + montopag
#   SI (montopag>mayor) ENTONCES
#      mayor=montopag
#      nombmay=nombre
#   FIN SI
#   SI (montopag>=10350 y montopag<=18450) ENTONCES
#       numcli = numcli + 1
#   FIN SI
#   IMPRIMIR ‘El monto a pagar por el cliente ’, nombre, ‘ es:’, montopag,’ Bs.’
#   IMPRIMIR ‘Desea Calcular otro vehiculo S/N’
#   REPITA
#     LEER resp
#   HASTA (resp == ‘S’ o resp == ‘N’ o resp == ‘s’ o resp == ‘n’)
# HASTA (resp==’N’ o resp==’n’)
# porccli=(numcli/Toclientes)*100
# IMPRIMIR ’El total recaudado en Bs. Es:’, Totalrec
# IMPRIMIR ’El numero de clientes que pago la tarifa minima Es:’, cantclimin
# IMPRIMIR ’El Cliente que pago la mayor factura es:’, nombmay
# IMPRIMIR ’El porcentaje de clientes entre 10350 y 18450 Bs:’, porccli
# FIN
# ```
